# %%
import pandas as pd

# %%
df = pd.read_json('ind-data.json')

# %%
df
# Out:
#                      id             provinsi
# 0                  Aceh                 Aceh
# 1                  Bali                 Bali
# 2       Bangka-Belitung      Bangka-Belitung
# 3                Banten               Banten
# 4              Bengkulu             Bengkulu
# 5             Gorontalo            Gorontalo
# 6      Irian Jaya Barat     Irian Jaya Barat
# 7          Jakarta Raya         Jakarta Raya
# 8                 Jambi                Jambi
# 9            Jawa Barat           Jawa Barat
# 10          Jawa Tengah          Jawa Tengah
# 11           Jawa Timur           Jawa Timur
# 12     Kalimantan Barat     Kalimantan Barat
# 13   Kalimantan Selatan   Kalimantan Selatan
# 14    Kalimantan Tengah    Kalimantan Tengah
# 15     Kalimantan Timur     Kalimantan Timur
# 16     Kalimantan Utara     Kalimantan Utara
# 17       Kepulauan Riau       Kepulauan Riau
# 18              Lampung              Lampung
# 19         Maluku Utara         Maluku Utara
# ...

# %%
df.loc[df.provinsi.str.contains('Bangka-belitung'), 'provinsi'] = 'Kepulauan Bangka Belitung'
df.loc[df.provinsi.str.contains('Irian Jaya Barat'), 'provinsi'] = 'Papua Barat'
df.loc[df.provinsi.str.contains('Jakarta Raya'), 'provinsi'] = 'Jakarta'
df.loc[df.provinsi.str.contains('Bangka-Belitung'), 'provinsi'] = 'Kepulauan Bangka Belitung'

# %%
provinsi = list((rev_df.drop_duplicates(['provinsi'])).provinsi)

# %%
df[df.provinsi.isin(provinsi) == False]
# Out:
# Empty DataFrame
# Columns: [id, provinsi]
# Index: []

# %%
df[df.provinsi != df.id]
# Out:
#                   id                   provinsi
# 2    Bangka-Belitung  Kepulauan Bangka Belitung
# 6   Irian Jaya Barat                Papua Barat
# 7       Jakarta Raya                    Jakarta
# 30    Sumatera Barat              Sumatra Barat
# 31  Sumatera Selatan            Sumatra Selatan
# 32    Sumatera Utara              Sumatra Utara

# %%
with open('./ind-data-prov-rev.json', 'w', encoding='utf-8') as outfile:
    outfile.write(df.to_json(orient='records'))

# %%
df = pd.read_json('./ind-data-prov-rev.json')
db = pd.read_json('./provinsi_bahasa.json')

# %%
df.loc[df.provinsi.str.contains('Sumatra Barat'), 'provinsi'] = 'Sumatera Barat'
df.loc[df.provinsi.str.contains('Sumatra Selatan'), 'provinsi'] = 'Sumatera Selatan'
df.loc[df.provinsi.str.contains('Sumatra Utara'), 'provinsi'] = 'Sumatera Utara'

# %%
merged = pd.merge(df, db, on='provinsi', how='left')

# %%
with open('./ind-data-prov-bahasa.json', 'w', encoding='utf-8') as outfile:
    outfile.write(merged.to_json(orient='records'))
